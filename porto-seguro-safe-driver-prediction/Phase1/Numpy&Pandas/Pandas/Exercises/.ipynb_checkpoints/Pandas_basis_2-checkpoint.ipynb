# %% [markdown]
# ## Pandas 数据分析连续（第二部分）
#
#
# <font color = red>注意：代码的输出，是我用标准答案run好的，不要run题目的chunk，输出会消失！另开一个代码块输入你的答案！！！</font>

# %% [markdown]
# ## 抽样

# %%
# 创建随机数df

import pandas as pd
import numpy as np

df = pd.read_csv('./Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### 简单抽样

# %%
# 随机抽取五行
df.sample(n=5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 6      7            4.6           3.4            1.4           0.3
# 19    20            5.1           3.8            1.5           0.3
# 93    94            5.0           2.3            3.3           1.0
# 135  136            7.7           3.0            6.1           2.3
# 113  114            5.7           2.5            5.0           2.0
#
#              Species
# 6        Iris-setosa
# 19       Iris-setosa
# 93   Iris-versicolor
# 135   Iris-virginica
# 113   Iris-virginica

# %%
# 每一次run这一chunk，都不会变
df.sample(n=5,random_state = 1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 14    15            5.8           4.0            1.2           0.2
# 98    99            5.1           2.5            3.0           1.1
# 75    76            6.6           3.0            4.4           1.4
# 16    17            5.4           3.9            1.3           0.4
# 131  132            7.9           3.8            6.4           2.0
#
#              Species
# 14       Iris-setosa
# 98   Iris-versicolor
# 75   Iris-versicolor
# 16       Iris-setosa
# 131   Iris-virginica

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# 加权抽样
sample = df.sample(n = 20,weights = [20]*50+[50]*50+[30]*50,random_state=1024)
sample
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 94    95            5.6           2.7            4.2           1.3
# 149  150            5.9           3.0            5.1           1.8
# 81    82            5.5           2.4            3.7           1.0
# 95    96            5.7           3.0            4.2           1.2
# 89    90            5.5           2.5            4.0           1.3
# 108  109            6.7           2.5            5.8           1.8
# 34    35            4.9           3.1            1.5           0.1
# 1      2            4.9           3.0            1.4           0.2
# 37    38            4.9           3.1            1.5           0.1
# 99   100            5.7           2.8            4.1           1.3
# 133  134            6.3           2.8            5.1           1.5
# 74    75            6.4           2.9            4.3           1.3
# 61    62            5.9           3.0            4.2           1.5
# 137  138            6.4           3.1            5.5           1.8
# 76    77            6.8           2.8            4.8           1.4
# 116  117            6.5           3.0            5.5           1.8
# 49    50            5.0           3.3            1.4           0.2
# 119  120            6.0           2.2            5.0           1.5
# 35    36            5.0           3.2            1.2           0.2
# 98    99            5.1           2.5            3.0           1.1
#
#              Species
# 94   Iris-versicolor
# 149   Iris-virginica
# 81   Iris-versicolor
# 95   Iris-versicolor
# 89   Iris-versicolor
# 108   Iris-virginica
# 34       Iris-setosa
# 1        Iris-setosa
# 37       Iris-setosa
# 99   Iris-versicolor
# 133   Iris-virginica
# 74   Iris-versicolor
# 61   Iris-versicolor
# 137   Iris-virginica
# 76   Iris-versicolor
# 116   Iris-virginica
# 49       Iris-setosa
# 119   Iris-virginica
# 35       Iris-setosa
# 98   Iris-versicolor

# %%
sample.Species.value_counts()
# Out:
# Iris-versicolor    9
# Iris-virginica     6
# Iris-setosa        5
# Name: Species, dtype: int64

# %% [markdown]
# `value_counts()` 可以统计categorical数据的对应类别的size
# 常用指数：⭐⭐⭐

# %%
sample.Species.value_counts()/sample.shape[0] # 求百分比
# Out:
# Iris-versicolor    0.45
# Iris-virginica     0.30
# Iris-setosa        0.25
# Name: Species, dtype: float64

# %% [markdown]
# 如何更直观的看它们的分布呢？

# %%
sample.Species.value_counts().plot(kind = 'bar', 
                                   title = 'count - Species',
                                   rot = 0,
                                   figsize = [8,4])
# Out:
# <AxesSubplot:title={'center':'count - Species'}>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 1</b>:
# <font color = red>第一题：df这个数据行太多了，我们用不到，所以在每一类别里，随机抽选5条样本吧！seed = 1</font>
#
#
# 1. df新增一列，命名为`Species_encoding`，当Species为setosa，则值为1，versicolor，则值为2，virginica，值为3（不能用if elif）【2分】
# 2. 根据每个`Species`进行抽样，在每一类别里，随机抽选5条样本，命名为`iris_sample`。【3分】
# </div>

# %%
# 不要run，在下面的代码块写答案
# Out:
#     index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      27   28            5.2           3.5            1.5           0.2
# 1      35   36            5.0           3.2            1.2           0.2
# 2      40   41            5.0           3.5            1.3           0.3
# 3      38   39            4.4           3.0            1.3           0.2
# 4       2    3            4.7           3.2            1.3           0.2
# 5      77   78            6.7           3.0            5.0           1.7
# 6      85   86            6.0           3.4            4.5           1.6
# 7      90   91            5.5           2.6            4.4           1.2
# 8      88   89            5.6           3.0            4.1           1.3
# 9      52   53            6.9           3.1            4.9           1.5
# 10    127  128            6.1           3.0            4.9           1.8
# 11    135  136            7.7           3.0            6.1           2.3
# 12    140  141            6.7           3.1            5.6           2.4
# 13    138  139            6.0           3.0            4.8           1.8
# 14    102  103            7.1           3.0            5.9           2.1
#
#             Species  Species_encoding
# 0       Iris-setosa                 1
# 1       Iris-setosa                 1
# 2       Iris-setosa                 1
# 3       Iris-setosa                 1
# 4       Iris-setosa                 1
# 5   Iris-versicolor                 2
# 6   Iris-versicolor                 2
# 7   Iris-versicolor                 2
# 8   Iris-versicolor                 2
# 9   Iris-versicolor                 2
# 10   Iris-virginica                 3
# 11   Iris-virginica                 3
# 12   Iris-virginica                 3
# 13   Iris-virginica                 3
# 14   Iris-virginica                 3

# %%
df.loc[(df.Species == 'Iris-setosa'), 'Species_encoding'] = 1
df.loc[(df.Species == 'Iris-versicolor'), 'Species_encoding'] = 2
df.loc[(df.Species == 'Iris-virginica'), 'Species_encoding'] = 3
s1 = df[df['Species_encoding'] == 1].sample(n=5, random_state=1)
s2 = df[df['Species_encoding'] == 2].sample(n=5, random_state=1)
s3 = df[df['Species_encoding'] == 3].sample(n=5, random_state=1)
iris_sample = pd.concat([s1, s2, s3]).reset_index()
iris_sample
# Out:
#     index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      27   28            5.2           3.5            1.5           0.2
# 1      35   36            5.0           3.2            1.2           0.2
# 2      40   41            5.0           3.5            1.3           0.3
# 3      38   39            4.4           3.0            1.3           0.2
# 4       2    3            4.7           3.2            1.3           0.2
# 5      77   78            6.7           3.0            5.0           1.7
# 6      85   86            6.0           3.4            4.5           1.6
# 7      90   91            5.5           2.6            4.4           1.2
# 8      88   89            5.6           3.0            4.1           1.3
# 9      52   53            6.9           3.1            4.9           1.5
# 10    127  128            6.1           3.0            4.9           1.8
# 11    135  136            7.7           3.0            6.1           2.3
# 12    140  141            6.7           3.1            5.6           2.4
# 13    138  139            6.0           3.0            4.8           1.8
# 14    102  103            7.1           3.0            5.9           2.1
#
#             Species  Species_encoding
# 0       Iris-setosa                 1
# 1       Iris-setosa                 1
# 2       Iris-setosa                 1
# 3       Iris-setosa                 1
# 4       Iris-setosa                 1
# 5   Iris-versicolor                 2
# 6   Iris-versicolor                 2
# 7   Iris-versicolor                 2
# 8   Iris-versicolor                 2
# 9   Iris-versicolor                 2
# 10   Iris-virginica                 3
# 11   Iris-virginica                 3
# 12   Iris-virginica                 3
# 13   Iris-virginica                 3
# 14   Iris-virginica                 3

# %% [markdown]
# ## 分组【groupby】上
#
# 那么如何根据类别对数据分组？
#
# groupby函数可以帮我们解决问题！
#
# 什么是groupby? 可以总结为3个步骤：
#
# 1. Splitting
#
# 根据分组标准，把数据拆分。
#
#
# 2. Applying
#
# 分组之后，目的是通过
#
#  - 聚合函数
#  - 转换函数
#  - 筛选函数
#
# 对组内数据进行操作（有实例）
#
# 3. Combining
#
#
# 今天这一期，我们只讲【Splitting】的部分！

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>注意：</b>
# 没有完成上一题目，无法向下进行哦，请务必完成上题，得到 iris_sample
# </div>

# %%
iris_sample.groupby('Species')  # 会得到一个DataFrameGroupBy对象

# %%
sample_group = iris_sample.groupby('Species')

# %%
list(sample_group) # 用list查看
# Out:
# [('Iris-setosa',
#      index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
#   0     27  28            5.2           3.5            1.5           0.2
#   1     35  36            5.0           3.2            1.2           0.2
#   2     40  41            5.0           3.5            1.3           0.3
#   3     38  39            4.4           3.0            1.3           0.2
#   4      2   3            4.7           3.2            1.3           0.2
#
#          Species  Species_encoding
#   0  Iris-setosa                 1
#   1  Iris-setosa                 1
#   2  Iris-setosa                 1
#   3  Iris-setosa                 1
#   4  Iris-setosa                 1  ),
#  ('Iris-versicolor',
#      index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
#   5     77  78            6.7           3.0            5.0           1.7
#   6     85  86            6.0           3.4            4.5           1.6
#   7     90  91            5.5           2.6            4.4           1.2
#   8     88  89            5.6           3.0            4.1           1.3
#   9     52  53            6.9           3.1            4.9           1.5
#
#              Species  Species_encoding
#   5  Iris-versicolor                 2
#   6  Iris-versicolor                 2
#   7  Iris-versicolor                 2
#   8  Iris-versicolor                 2
#   9  Iris-versicolor                 2  ),
#  ('Iris-virginica',
#       index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
#   10    127  128            6.1           3.0            4.9           1.8
#   11    135  136            7.7           3.0            6.1           2.3
#   12    140  141            6.7           3.1            5.6           2.4
#   13    138  139            6.0           3.0            4.8           1.8
#   14    102  103            7.1           3.0            5.9           2.1
#
#              Species  Species_encoding
#   10  Iris-virginica                 3
#   11  Iris-virginica                 3
#   12  Iris-virginica                 3
#   13  Iris-virginica                 3
#   14  Iris-virginica                 3  )]

# %%
# .ngroups 查看有几组
sample_group.ngroups
# Out:
# 3

# %%
# .size() 查看组内容量
sample_group.size()
# Out:
# Species
# Iris-setosa        5
# Iris-versicolor    5
# Iris-virginica     5
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 2</b>:
#
# 第二题：基于`sample_group`
#
#
# 1. 返回一个df，叫first，为每个group的第一行数据合并【1分】
# 2. 返回一个df，叫last，为每个group的最后一行数据合并 【1分】
# </div>

# %%
# first
# Out:
#                  index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa         27   28            5.2           3.5            1.5
# Iris-versicolor     77   78            6.7           3.0            5.0
# Iris-virginica     127  128            6.1           3.0            4.9
#
#                  PetalWidthCm  Species_encoding
# Species
# Iris-setosa               0.2                 1
# Iris-versicolor           1.7                 2
# Iris-virginica            1.8                 3

# %%
s1 = pd.DataFrame(list(sample_group)[0][1].iloc[0]).T
s2 = pd.DataFrame(list(sample_group)[1][1].iloc[0]).T
s3 = pd.DataFrame(list(sample_group)[2][1].iloc[0]).T
first = pd.concat([s1, s2, s3])
first.set_index('Species', inplace=True)
first
# Out:
#                 index   Id SepalLengthCm SepalWidthCm PetalLengthCm  \
# Species
# Iris-setosa        27   28           5.2          3.5           1.5
# Iris-versicolor    77   78           6.7          3.0           5.0
# Iris-virginica    127  128           6.1          3.0           4.9
#
#                 PetalWidthCm Species_encoding
# Species
# Iris-setosa              0.2                1
# Iris-versicolor          1.7                2
# Iris-virginica           1.8                3

# %%
# last
# Out:
#                  index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa          2    3            4.7           3.2            1.3
# Iris-versicolor     52   53            6.9           3.1            4.9
# Iris-virginica     102  103            7.1           3.0            5.9
#
#                  PetalWidthCm  Species_encoding
# Species
# Iris-setosa               0.2                 1
# Iris-versicolor           1.5                 2
# Iris-virginica            2.1                 3

# %%
last = pd.DataFrame()
for group in sample_group:
    last = pd.concat([last, pd.DataFrame(list(group)[1].iloc[-1]).T])
last.set_index('Species', inplace=True)
last
# Out:
#                 index   Id SepalLengthCm SepalWidthCm PetalLengthCm  \
# Species
# Iris-setosa         2    3           4.7          3.2           1.3
# Iris-versicolor    52   53           6.9          3.1           4.9
# Iris-virginica    102  103           7.1          3.0           5.9
#
#                 PetalWidthCm Species_encoding
# Species
# Iris-setosa              0.2                1
# Iris-versicolor          1.5                2
# Iris-virginica           2.1                3

# %%
# 根据分组的名称取出对应数据
sample_group.get_group('Iris-setosa')
# Out:
#    index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     27  28            5.2           3.5            1.5           0.2
# 1     35  36            5.0           3.2            1.2           0.2
# 2     40  41            5.0           3.5            1.3           0.3
# 3     38  39            4.4           3.0            1.3           0.2
# 4      2   3            4.7           3.2            1.3           0.2
#
#        Species  Species_encoding
# 0  Iris-setosa                 1
# 1  Iris-setosa                 1
# 2  Iris-setosa                 1
# 3  Iris-setosa                 1
# 4  Iris-setosa                 1

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 3</b>:
#
# 第三题：基于`sample_group`【提示：filter】
#
#
# 请问那组数据的`SepalWidthCm`的最大值大于3.2，并且`PetalWidthCm`的最小值小于1【2分】
#
# </div>

# %%
# Out:
#    index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     27  28            5.2           3.5            1.5           0.2
# 1     35  36            5.0           3.2            1.2           0.2
# 2     40  41            5.0           3.5            1.3           0.3
# 3     38  39            4.4           3.0            1.3           0.2
# 4      2   3            4.7           3.2            1.3           0.2
#
#        Species  Species_encoding
# 0  Iris-setosa                 1
# 1  Iris-setosa                 1
# 2  Iris-setosa                 1
# 3  Iris-setosa                 1
# 4  Iris-setosa                 1

# %%
sample_group.filter(lambda x: (x['SepalWidthCm'].max() > 3.2) & (x['PetalWidthCm'].min() < 1))
# Out:
#    index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     27  28            5.2           3.5            1.5           0.2
# 1     35  36            5.0           3.2            1.2           0.2
# 2     40  41            5.0           3.5            1.3           0.3
# 3     38  39            4.4           3.0            1.3           0.2
# 4      2   3            4.7           3.2            1.3           0.2
#
#        Species  Species_encoding
# 0  Iris-setosa                 1
# 1  Iris-setosa                 1
# 2  Iris-setosa                 1
# 3  Iris-setosa                 1
# 4  Iris-setosa                 1

# %% [markdown]
# ## 小结
#
# 今天就分享到这里，总结一下！
#
# 1. 抽样以及具体参数用法
# 2. groupby的Splitting以及group的基本manipulation
